# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import sklearn

# %%
df = pd.read_csv("spam.csv",encoding="ISO-8859-1")

# %%
df.head(3)
# Out:
#    target                                               text  nums_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
#
#    nums_words  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...

# %%
df.sample(3)
# Out:
#       target                                               text  \
# 2267       0                                  Finish liao... U?
# 3512       0     Staff of placement training in Amrita college.
# 3014       0   &lt;#&gt;  mins but i had to stop somewhere f...
#
#       nums_characters  nums_words  num_sentences  \
# 2267               17           5              1
# 3512               46           8              1
# 3014               51          16              1
#
#                          transformed_text
# 2267                        finish liao u
# 3512  staff placement train amrita colleg
# 3014        lt gt min stop somewher first

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data cleaning
# 2. EDA
# 3. Text preprocessing
# 4. model building 
# 5. evaluation 
# 6. improvement
# 7. website
# 8. deploy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 cols
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)

# %%
df.sample(3)
# Out:
#       target                                               text  \
# 1729       0                 Lol yeah at this point I guess not
# 5384       0  How are you babes. Hope your doing ok. I had a...
# 1799       0       If we hit it off, you can move in with me :)
#
#       nums_characters  nums_words  num_sentences  \
# 1729               34           8              1
# 5384              161          36              6
# 1799               44          14              1
#
#                                        transformed_text
# 1729                               lol yeah point guess
# 5384  babe hope shit night sleep fell asleep knacker...
# 1799                                           hit move

# %%
# renaming the cols
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df.sample(3)
# Out:
#       target                                               text  \
# 4098       0                If u dun drive then how i go 2 sch.
# 5316       0                       Jus finish watching tv... U?
# 5479       0  Really do hope the work doesnt get stressful. ...
#
#       nums_characters  nums_words  num_sentences  \
# 4098               35          11              1
# 5316               28           7              1
# 5479               61          14              2
#
#                                 transformed_text
# 4098                        u dun drive go 2 sch
# 5316                        ju finish watch tv u
# 5479  realli hope work doesnt get stress gr8 day

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head(3)
# Out:
#    target                                               text  nums_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
#
#    nums_words  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...

# %%
# missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# drop duplicate
df=df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # EDA

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
plt.pie(df['target'].value_counts(),autopct="%0.2f%%",labels=["Ham","Spam"],labeldistance=0.8)
plt.title("SMS")

plt.show()

# %%
# data is immalanced

# %%
import nltk

# %%
# 1. number of character in sms
# 2. number of words in sms
# 3. number of sentences in sms

# %%
df['nums_characters'] = df['text'].apply(len)

# %%
df.head(3)
# Out:
#    target                                               text  nums_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
#
#    nums_words  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...

# %%
plt.scatter(df['target'],df['nums_characters'])
plt.xlabel('target')
plt.ylabel("length of sms")
plt.title("sms Vs length")
plt.show()

# %%
# numbers of words
df['nums_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
# numbers of sentences
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head(3)
# Out:
#    target                                               text  nums_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
#
#    nums_words  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...

# %%
# for ham
df[df['target']==0].describe()
# Out:
#        target  nums_characters   nums_words  num_sentences
# count  4516.0      4516.000000  4516.000000    4516.000000
# mean      0.0        70.459256    17.123782       1.820195
# std       0.0        56.358207    13.493970       1.383657
# min       0.0         2.000000     1.000000       1.000000
# 25%       0.0        34.000000     8.000000       1.000000
# 50%       0.0        52.000000    13.000000       1.000000
# 75%       0.0        90.000000    22.000000       2.000000
# max       0.0       910.000000   220.000000      38.000000

# %%
# for spam
df[df['target']==1].describe()
# Out:
#        target  nums_characters  nums_words  num_sentences
# count   653.0       653.000000  653.000000     653.000000
# mean      1.0       137.891271   27.667688       2.970904
# std       0.0        30.137753    7.008418       1.488425
# min       1.0        13.000000    2.000000       1.000000
# 25%       1.0       132.000000   25.000000       2.000000
# 50%       1.0       149.000000   29.000000       3.000000
# 75%       1.0       157.000000   32.000000       4.000000
# max       1.0       224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['nums_characters'])
sns.histplot(df[df['target'] == 1]['nums_characters'],color='red')
# plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['nums_words'])
sns.histplot(df[df['target'] == 1]['nums_words'],color='red')
# plt.legend()
plt.show()

# %%
sns.pairplot(df,hue='target')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# . Lower case
# . tokenization
# . removing special characters
# . removing stop words and punctuation
# . stemming( dance, dancing)

# %%
def transform_text(text):
    text = text.lower()
    text= nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)

    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
transform_text("Are you crazy ?")
# Out:
# ['crazy']

# %%
transform_text("I loved the YT lectures on Machine Learning. How about you? ")
# Out:
# 'love yt lectur machin learn'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
# stopwords.words('english')

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('dancing')
# Out:
# 'danc'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head(3)
# Out:
#    target                                               text  nums_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
#
#    nums_words  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...

# %%
from wordcloud import WordCloud
WC = WordCloud(width =500, height=500,min_font_size=10,background_color="white")

# %%
spam_wc = WC.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc = WC.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head(3)
# Out:
#    target                                               text  nums_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
#
#    nums_words  num_sentences  \
# 0          24              2
# 1           8              2
# 2          37              2
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...

# %% [markdown]
# # Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
x = cv.fit_transform(df['transformed_text']).toarray()

# %%
x.shape
# Out:
# (5169, 6708)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
gnb = GaussianNB()
mnd = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train, Y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(Y_test, y_pred1))
print(confusion_matrix(Y_test, y_pred1))
print(precision_score(Y_test, y_pred1))
# Out:
# 0.8800773694390716
# [[792 104]
#  [ 20 118]]
# 0.5315315315315315

# %%
mnd.fit(X_train, Y_train)
y_pred2 = mnd.predict(X_test)
print(accuracy_score(Y_test, y_pred2))
print(confusion_matrix(Y_test, y_pred2))
print(precision_score(Y_test, y_pred2))
# Out:
# 0.9642166344294004
# [[871  25]
#  [ 12 126]]
# 0.8344370860927153

# %%
bnb.fit(X_train, Y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(Y_test, y_pred3))
print(confusion_matrix(Y_test, y_pred3))
print(precision_score(Y_test, y_pred3))
# Out:
# 0.9700193423597679
# [[893   3]
#  [ 28 110]]
# 0.9734513274336283
